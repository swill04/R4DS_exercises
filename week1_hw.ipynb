# %% [markdown]
# # Running Exercises

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.5.1     ✔ purrr   1.0.2
# ✔ tibble  3.2.1     ✔ dplyr   1.1.4
# ✔ tidyr   1.3.1     ✔ stringr 1.5.1
# ✔ readr   2.1.5     ✔ forcats 1.0.0
# Warning message:
# “package ‘ggplot2’ was built under R version 4.2.3”
# Warning message:
# “package ‘tibble’ was built under R version 4.2.3”
# Warning message:
# “package ‘tidyr’ was built under R version 4.2.3”
# Warning message:
# “package ‘readr’ was built under R version 4.2.3”
# Warning message:
# “package ‘purrr’ was built under R version 4.2.3”
# Warning message:
# “package ‘dplyr’ was built under R version 4.2.3”
# Warning message:
# “package ‘stringr’ was built under R version 4.2.3”
# Warning message:
# “package ‘forcats’ was built under R version 4.2.3”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
install.packages('palmerpenguins')
install.packages('ggthemes')
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
library(palmerpenguins)
library(ggthemes)

# %%
penguins
# Out:
#     species   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Adelie    Torgersen 39.1           18.7          181
# 2   Adelie    Torgersen 39.5           17.4          186
# 3   Adelie    Torgersen 40.3           18.0          195
# 4   Adelie    Torgersen   NA             NA           NA
# 5   Adelie    Torgersen 36.7           19.3          193
# 6   Adelie    Torgersen 39.3           20.6          190
# 7   Adelie    Torgersen 38.9           17.8          181
# 8   Adelie    Torgersen 39.2           19.6          195
# 9   Adelie    Torgersen 34.1           18.1          193
# 10  Adelie    Torgersen 42.0           20.2          190
# 11  Adelie    Torgersen 37.8           17.1          186
# 12  Adelie    Torgersen 37.8           17.3          180
# 13  Adelie    Torgersen 41.1           17.6          182
# 14  Adelie    Torgersen 38.6           21.2          191
# 15  Adelie    Torgersen 34.6           21.1          198
# ...

# %%
glimpse(penguins)
# Out:
# Rows: 344
# Columns: 8
# $ species           <fct> Adelie, Adelie, Adelie, Adelie, Adelie, Adelie, Adel…
# $ island            <fct> Torgersen, Torgersen, Torgersen, Torgersen, Torgerse…
# $ bill_length_mm    <dbl> 39.1, 39.5, 40.3, NA, 36.7, 39.3, 38.9, 39.2, 34.1, …
# $ bill_depth_mm     <dbl> 18.7, 17.4, 18.0, NA, 19.3, 20.6, 17.8, 19.6, 18.1, …
# $ flipper_length_mm <int> 181, 186, 195, NA, 193, 190, 181, 195, 193, 190, 186…
# $ body_mass_g       <int> 3750, 3800, 3250, NA, 3450, 3650, 3625, 4675, 3475, …
# $ sex               <fct> male, female, female, NA, female, male, female, male…
# $ year              <int> 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007…

# %%
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g)
) +
  geom_point(aes(color = species, shape = species)) +
  geom_smooth(method = "lm") +
  labs(
    title = "Body mass and flipper length",
    subtitle = "Dimensions for Adelie, Chinstrap, and Gentoo Penguins",
    x = "Flipper length (mm)", y = "Body mass (g)",
    color = "Species", shape = "Species"
  ) +
  scale_color_colorblind()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# # Homework Assignments

# %% [markdown]
# ## 1.2.5 Exercises

# %% [markdown]
# 1. How many rows are in penguins? How many columns?

# %% [markdown]
# Answer: There are 344 rows and 8 columns

# %%
glimpse(penguins)
# Out:
# Rows: 344
# Columns: 8
# $ species           <fct> Adelie, Adelie, Adelie, Adelie, Adelie, Adelie, Adel…
# $ island            <fct> Torgersen, Torgersen, Torgersen, Torgersen, Torgerse…
# $ bill_length_mm    <dbl> 39.1, 39.5, 40.3, NA, 36.7, 39.3, 38.9, 39.2, 34.1, …
# $ bill_depth_mm     <dbl> 18.7, 17.4, 18.0, NA, 19.3, 20.6, 17.8, 19.6, 18.1, …
# $ flipper_length_mm <int> 181, 186, 195, NA, 193, 190, 181, 195, 193, 190, 186…
# $ body_mass_g       <int> 3750, 3800, 3250, NA, 3450, 3650, 3625, 4675, 3475, …
# $ sex               <fct> male, female, female, NA, female, male, female, male…
# $ year              <int> 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007…

# %% [markdown]
# 2. What does the bill_depth_mm variable in the penguins data frame describe? Read the help for ?penguins to find out.

# %% [markdown]
# Answer: A number that denotes bill depth in millimeters.

# %%
?penguins
# Out:
# penguins            package:palmerpenguins             R Documentation
#
# n,
# a
#
# n:
#
#      Includes measurements for penguin species, island in Palmer
#      Archipelago, size (flipper length, body mass, bill dimensions),
#      and sex. This is a subset of ‘penguins_raw’.
#
# e:
#
#      penguins
#
# t:
#
#      A tibble with 344 rows and 8 variables:
#
#      species a factor denoting penguin species (Adélie, Chinstrap and
#           Gentoo)
#
#      island a factor denoting island in Palmer Archipelago, Antarctica
#           (Biscoe, Dream or Torgersen)
#
#      bill_length_mm a number denoting bill length (millimeters)
#
#      bill_depth_mm a number denoting bill depth (millimeters)
#
#      flipper_length_mm an integer denoting flipper length (millimeters)
#
#      body_mass_g an integer denoting body mass (grams)
#
#      sex a factor denoting penguin sex (female, male)
#
#      year an integer denoting the study year (2007, 2008, or 2009)
#
# e:
#
# ...

# %% [markdown]
# 3. Make a scatterplot of bill_depth_mm vs. bill_length_mm. That is, make a scatterplot with bill_depth_mm on the y-axis and bill_length_mm on the x-axis. Describe the relationship between these two variables.

# %% [markdown]
# Answer: It appears that the points are pretty scattered. There does seem to be a slight relationship with a smaller bill length (<40) relating to a longer bill depth as well as a longer bill length (40-50mm) relating to a shorter bill depth.

# %%
ggplot(
    data = penguins,
    mapping = aes(x = bill_length_mm, y = bill_depth_mm)
) +
    geom_point()
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# 4. What happens if you make a scatterplot of species vs. bill_depth_mm? What might be a better choice of geom?

# %% [markdown]
# Answer: Doing a boxplot allows you to see the bill depth separated by each species as well as the median, upper and lower bounded values, and each quartile.

# %%
ggplot(
    data = penguins,
    mapping = aes(x = bill_depth_mm, y = species)
) +
    geom_boxplot()
# Out:
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range
# (`stat_boxplot()`).”
# plot without title

# %% [markdown]
# 5. Why does the following give an error and how would you fix it?
# ```r
# ggplot(data = penguins) +
#   geom_point()
# ```

# %% [markdown]
# Answer: The error is caused because geom_point() isn't provided what observations it's going to be mapping from the penguins dataset. Adding in the mapping variable with aes() will fix this.

# %%
ggplot(
    data = penguins,
    mapping = aes(x = flipper_length_mm, y = body_mass_g)
) +
    geom_point()
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# 6. What does the na.rm argument do in geom_point()? What is the default value of the argument? Create a scatterplot where you successfully use this argument set to TRUE.

# %% [markdown]
# Answer: The na.rm argument removes observations with missing values. The default is FALSE which will remove the NA values with a warning attached. Setting to TRUE removes the warning message.

# %%
ggplot(
    data = penguins,
    mapping = aes(x = flipper_length_mm, y = bill_depth_mm)
) +
    geom_point(na.rm = TRUE)
# Out:
# plot without title

# %% [markdown]
# 7. Add the following caption to the plot you made in the previous exercise: “Data come from the palmerpenguins package.” Hint: Take a look at the documentation for labs().

# %%
ggplot(
    data = penguins,
    mapping = aes(x = flipper_length_mm, y = bill_depth_mm)
) +
    geom_point(na.rm = TRUE) +
    labs(
        subtitle = 'Data come from the palmerpenguins package.'
    )
# Out:
# plot without title

# %% [markdown]
# 8. Recreate the following visualization. What aesthetic should bill_depth_mm be mapped to? And should it be mapped at the global level or at the geom level?

# %% [markdown]
# Answer: bill_depth_mm is mapped to the geom_point() color aesthetic in aes(). It's mapped at the geom level because we want there to not be separation in the line.

# %%
ggplot(
    data = penguins,
    mapping = aes(x = flipper_length_mm, y = body_mass_g)
) +
    geom_point(mapping = aes(color = bill_depth_mm)) +
    geom_smooth(method = 'lm')
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# 9. Run this code in your head and predict what the output will look like. Then, run the code in R and check your predictions.
# ```r
# ggplot(
#   data = penguins,
#   mapping = aes(x = flipper_length_mm, y = body_mass_g, color = island)
# ) +
#   geom_point() +
#   geom_smooth(se = FALSE)
# ```

# %% [markdown]
# Answer: I predict that the output will be a scatterplot of body_mass_g vs flipper_length_mm with the confidence interval on the smoothing line removed so it's a plain line for each island type.

# %%
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g, color = island)
) +
  geom_point() +
  geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# 10. Will these two graphs look different? Why/why not?
# ```r
# ggplot(
#   data = penguins,
#   mapping = aes(x = flipper_length_mm, y = body_mass_g)
# ) +
#   geom_point() +
#   geom_smooth()
#
# ggplot() +
#   geom_point(
#     data = penguins,
#     mapping = aes(x = flipper_length_mm, y = body_mass_g)
#   ) +
#   geom_smooth(
#     data = penguins,
#     mapping = aes(x = flipper_length_mm, y = body_mass_g)
#   )
# ```

# %% [markdown]
# Answer: These two graphs won't look different because the mapping aesthetics are the same even though the format of the plotting lines are different. In the first it combines what the geom_point() and geom_smooth() will use for variables. In the second, it explicitly states what each uses for it's input.

# %%
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g)
) +
  geom_point() +
  geom_smooth()

ggplot() +
  geom_point(
    data = penguins,
    mapping = aes(x = flipper_length_mm, y = body_mass_g)
  ) +
  geom_smooth(
    data = penguins,
    mapping = aes(x = flipper_length_mm, y = body_mass_g)
  )
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title
# plot without title

# %% [markdown]
# ## 1.4.3 Exercises

# %% [markdown]
# 1. Make a bar plot of species of penguins, where you assign species to the y aesthetic. How is this plot different?

# %% [markdown]
# Answer: This plot has the species on the left side on the y-axis with the counts on the x-axis. It's an inverted view of a regular barplot where the species is on the x-axis and the count is on the y-axis.

# %%
ggplot(penguins, aes(y = species)) +
geom_bar()
# Out:
# plot without title

# %% [markdown]
# 2. How are the following two plots different? Which aesthetic, color or fill, is more useful for changing the color of bars?
# ```r
# ggplot(penguins, aes(x = species)) +
#   geom_bar(color = "red")
#
# ggplot(penguins, aes(x = species)) +
#   geom_bar(fill = "red")
# ```

# %% [markdown]
# Answer: The first only colors the outline of the bars whereas the second changes the outline as well as the entire area within the bar. Fill is a better aesthetic for changing the color of the bars because it's completely filled rather than being outlined.

# %%
ggplot(penguins, aes(x = species)) +
  geom_bar(color = "red")

ggplot(penguins, aes(x = species)) +
  geom_bar(fill = "red")
# Out:
# plot without title
# plot without title

# %% [markdown]
# 3. What does the bins argument in geom_histogram() do?

# %% [markdown]
# Answer: The bins argument in geom_histogram() sets the width of the intervals/bars in the histogram.

# %% [markdown]
# 4. Make a histogram of the carat variable in the diamonds dataset that is available when you load the tidyverse package. Experiment with different binwidths. What binwidth reveals the most interesting patterns?

# %% [markdown]
# Answer: Going up past 100 bins makes the bars extremely thin and a little hard to see. Anything below ~ 50 bins makes the bars seem to melt together. It becomes harder to distinguish the bars from one another

# %%
ggplot(diamonds, aes(x=carat)) +
    geom_histogram(bins = 30)
# Out:
# plot without title

# %% [markdown]
# ## 1.5.5 Exercises

# %% [markdown]
# 1. The mpg data frame that is bundled with the ggplot2 package contains 234 observations collected by the US Environmental Protection Agency on 38 car models. Which variables in mpg are categorical? Which variables are numerical? (Hint: Type ?mpg to read the documentation for the dataset.) How can you see this information when you run mpg?

# %% [markdown]
# Answer: Categorical variables are: manufacturer, model, year, cyl, trans, drv, fl, and class. Numerical variables are: displ, cty, and hwy. I can see this information based on what the categories are below the variables. Most often, < chr > are categorical whereas < dbl > or < int > are numerical. However, in some cases, like year or cyl where it's a categorical but is represented by a number.

# %%
mpg
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# ...

# %%
?mpg
# Out:
# mpg                  package:ggplot2                   R Documentation
#
# s
#
# n:
#
#      This dataset contains a subset of the fuel economy data that the
#      EPA makes available on <https://fueleconomy.gov/>. It contains
#      only models which had a new release every year between 1999 and
#      2008 - this was used as a proxy for the popularity of the car.
#
# e:
#
#      mpg
#
# t:
#
#      A data frame with 234 rows and 11 variables:
#
#      manufacturer manufacturer name
#
#      model model name
#
#      displ engine displacement, in litres
#
#      year year of manufacture
#
#      cyl number of cylinders
#
#      trans type of transmission
#
#      drv the type of drive train, where f = front-wheel drive, r = rear
#           wheel drive, 4 = 4wd
#
#      cty city miles per gallon
#
#      hwy highway miles per gallon
#
#      fl fuel type
#
#      class "type" of car

# %% [markdown]
# 2. Make a scatterplot of hwy vs. displ using the mpg data frame. Next, map a third, numerical variable to color, then size, then both color and size, then shape. How do these aesthetics behave differently for categorical vs. numerical variables?

# %% [markdown]
# Answer: For mapping color, the aesthetic behaves normally for a numerical variable. When changing to categorical, due to the wide range of options, it doesn't appear as good as using a numerical. For size, using a numerical changes the points to be a different size depending on the variable chosen. With categorical, it appears the same but does mention a warning. With color and size, it combines what was shown in both the color graph and the size graph. For changing shape, I had to pick a categorical variable as it wouldn't allow me to choose a numerical variable. This changed the points based on the drv (type of drive train).

# %%
ggplot(mpg, aes(x = displ, y = hwy)) +
    geom_point()
# Out:
# plot without title

# %%
ggplot(mpg, aes(x = displ, y = hwy, color = displ)) +
    geom_point()
# Out:
# plot without title

# %%
ggplot(mpg, aes(x = displ, y = hwy, size = displ)) +
    geom_point()
# Out:
# plot without title

# %%
ggplot(mpg, aes(x = displ, y = hwy, color = displ, size = displ)) +
    geom_point()
# Out:
# plot without title

# %%
ggplot(mpg, aes(x = displ, y = hwy)) +
    geom_point(aes(shape = drv))
# Out:
# plot without title

# %% [markdown]
# 3. In the scatterplot of hwy vs. displ, what happens if you map a third variable to linewidth?

# %% [markdown]
# Answer: Nothing happens because the plot is a scatterplot. To make linewidth perform a difference, it needs to be a density plot. There is warning producedthat states "using linewidth for a discrete variable is not advised." Also, linewidth would work better if provided with a numerical variable rather than a variable that is from the dataset.

# %%
ggplot(mpg, aes(x = displ, y = hwy, linewidth = drv)) +
    geom_point()
# Out:
# Warning message:
# “Using linewidth for a discrete variable is not advised.”
# plot without title

# %% [markdown]
# 4. What happens if you map the same variable to multiple aesthetics?

# %% [markdown]
# Answer: When mapping the variable to mutliple aesthetics, it adds each of the attributes together in the plot produced.

# %%
ggplot(mpg, aes(x = displ, y = hwy, color = drv, shape = drv, fill = drv)) +
    geom_point()
# Out:
# plot without title

# %% [markdown]
# 5. Make a scatterplot of bill_depth_mm vs. bill_length_mm and color the points by species. What does adding coloring by species reveal about the relationship between these two variables? What about faceting by species?

# %% [markdown]
# Answer: By coloring by species, I can see better which species has a potential relationship between bill depth and bill length in size. It appears that Gentoo have the smallest and shallowest bills. Whereas Adelie have a shorter but deep bill and Chinstrap have both a longer and deeper bill. By faceting by species, it separates out the graph into each respective species. Now, the relationship comparisons are easier to make between the species because they are all less clustered together.

# %%
ggplot(penguins, aes(x = bill_length_mm, y = bill_depth_mm)) +
    geom_point(aes(color = species))
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
ggplot(penguins, aes(x = bill_length_mm, y = bill_depth_mm)) +
    geom_point(aes(color = species)) +
    facet_wrap(~species)
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# 6. Why does the following yield two separate legends? How would you fix it to combine the two legends?
# ```r
# ggplot(
#   data = penguins,
#   mapping = aes(
#     x = bill_length_mm, y = bill_depth_mm,
#     color = species, shape = species
#   )
# ) +
#   geom_point() +
#   labs(color = "Species")
# ```

# %% [markdown]
# Answer: It yields two legends because color is set equal to species in two separate places (in the mapping and in the labels). To combine them, removing the labs(color = 'Species') will fix it.

# %%
ggplot(
  data = penguins,
  mapping = aes(
    x = bill_length_mm, y = bill_depth_mm, 
    color = species, shape = species
  )
) +
  geom_point() +
  labs(color = "Species")
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
ggplot(
  data = penguins,
  mapping = aes(
    x = bill_length_mm, y = bill_depth_mm, 
    color = species, shape = species
  )
) +
  geom_point()
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# 7. Create the two following stacked bar plots. Which question can you answer with the first one? Which question can you answer with the second one?
# ```r
# ggplot(penguins, aes(x = island, fill = species)) +
#   geom_bar(position = "fill")
# ggplot(penguins, aes(x = species, fill = island)) +
#   geom_bar(position = "fill")
# ```

# %% [markdown]
# Answer: For the first one, I can tell the how many of each species are on each island (Almost 75% of the population on Biscoe is Gentoo). For the second, I can tell which island the species is found on (the Chinstrap species is only located on Dream island yet Adelie is located on all three islands).

# %%
ggplot(penguins, aes(x = island, fill = species)) +
  geom_bar(position = "fill")
ggplot(penguins, aes(x = species, fill = island)) +
  geom_bar(position = "fill")
# Out:
# plot without title
# plot without title

# %% [markdown]
# ## 1.6.1 Exercises

# %% [markdown]
# 1. Run the following lines of code. Which of the two plots is saved as mpg-plot.png? Why?
# ```r
# ggplot(mpg, aes(x = class)) +
#   geom_bar()
# ggplot(mpg, aes(x = cty, y = hwy)) +
#   geom_point()
# ggsave("mpg-plot.png")
# ```

# %% [markdown]
# Answer: The geom_point() plot is saved. This is because ggsave() saves the plot most recently created to disk (or last plot displayed).

# %%
ggplot(mpg, aes(x = class)) +
  geom_bar()
ggplot(mpg, aes(x = cty, y = hwy)) +
  geom_point()
ggsave("mpg-plot.png")
# Out:
# plot without title
# Saving 6.67 x 6.67 in image
# plot without title

# %% [markdown]
# 2. What do you need to change in the code above to save the plot as a PDF instead of a PNG? How could you find out what types of image files would work in ggsave()?

# %% [markdown]
# Answer: You can change the code to say:
# ```r
# ggsave("mpg-plot.pdf")
# ```
# This will save it as a pdf instead. I found this out by doing ?ggsave() and looking in the arguments section

# %%
?ggsave()
# Out:
# ggsave                 package:ggplot2                 R Documentation
#
# s
#
# n:
#
#      ‘ggsave()’ is a convenient function for saving a plot. It defaults
#      to saving the last plot that you displayed, using the size of the
#      current graphics device. It also guesses the type of graphics
#      device from the extension.
#
# e:
#
#      ggsave(
#        filename,
#        plot = last_plot(),
#        device = NULL,
#        path = NULL,
#        scale = 1,
#        width = NA,
#        height = NA,
#        units = c("in", "cm", "mm", "px"),
#        dpi = 300,
#        limitsize = TRUE,
#        bg = NULL,
#        create.dir = FALSE,
#        ...
#      )
#
# s:
#
# filename: File name to create on disk.
#
#     plot: Plot to save, defaults to last plot displayed.
#
#   device: Device to use. Can either be a device function (e.g. png), or
#           one of "eps", "ps", "tex" (pictex), "pdf", "jpeg", "tiff",
# ...

# %% [markdown]
# ## 2.5 Exercises

# %% [markdown]
# 1. Why does this code not work?
# ```r
# my_variable <- 10
# my_varıable
# #> Error: object 'my_varıable' not found
# ```
# Look carefully! (This may seem like an exercise in pointlessness, but training your brain to notice even the tiniest difference will pay off when programming.)

# %% [markdown]
# Answer: When calling my_variable, the user wrote my_var1able with a 1 instead of an i. This doesn't match the original variable.

# %% [markdown]
# 2. Tweak each of the following R commands so that they run correctly:
# ```r
# libary(todyverse)
#
# ggplot(dTA = mpg) +
#   geom_point(maping = aes(x = displ y = hwy)) +
#   geom_smooth(method = "lm)
# ```

# %%
library(tidyverse)

ggplot(data = mpg) +
    geom_point(mapping = aes(x = displ, y = hwy)) +
    geom_smooth(mapping = aes(x = displ, y = hwy), method = 'lm')
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# 3. Press Option + Shift + K / Alt + Shift + K. What happens? How can you get to the same place using the menus?

# %% [markdown]
# Answer: This is done in RStudio - get keyboard shortcuts reference guide.

# %% [markdown]
# 4. Let’s revisit an exercise from the Section 1.6. Run the following lines of code. Which of the two plots is saved as mpg-plot.png? Why?
# ```r
# my_bar_plot <- ggplot(mpg, aes(x = class)) +
#   geom_bar()
# my_scatter_plot <- ggplot(mpg, aes(x = cty, y = hwy)) +
#   geom_point()
# ggsave(filename = "mpg-plot.png", plot = my_bar_plot)
# ```

# %% [markdown]
# Answer: my_bar_plot is saved in "mpg-plot.png". This is because the plot is specified in plot = my_bar_plot in the ggsave() function.

# %%
my_bar_plot <- ggplot(mpg, aes(x = class)) +
  geom_bar()
my_scatter_plot <- ggplot(mpg, aes(x = cty, y = hwy)) +
  geom_point()
ggsave(filename = "mpg-plot.png", plot = my_bar_plot)
# Out:
# Saving 6.67 x 6.67 in image
