# %% [markdown]
# # Running Exercises

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.5.1     ✔ purrr   1.0.2
# ✔ tibble  3.2.1     ✔ dplyr   1.1.4
# ✔ tidyr   1.3.1     ✔ stringr 1.5.1
# ✔ readr   2.1.5     ✔ forcats 1.0.0
# Warning message:
# “package ‘ggplot2’ was built under R version 4.2.3”
# Warning message:
# “package ‘tibble’ was built under R version 4.2.3”
# Warning message:
# “package ‘tidyr’ was built under R version 4.2.3”
# Warning message:
# “package ‘readr’ was built under R version 4.2.3”
# Warning message:
# “package ‘purrr’ was built under R version 4.2.3”
# Warning message:
# “package ‘dplyr’ was built under R version 4.2.3”
# Warning message:
# “package ‘stringr’ was built under R version 4.2.3”
# Warning message:
# “package ‘forcats’ was built under R version 4.2.3”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
install.packages('scales')
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
install.packages('ggrepel')
# Out:
# Warning message in install.packages("ggrepel"):
# “installation of package ‘ggrepel’ had non-zero exit status”
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %% [markdown]
# Running into errors with downloading ggrepel - not sure how to fix

# %%
library(ggrepel)
# Out:
# Error in library(ggrepel): there is no package called ‘ggrepel’
# Traceback:
#
# 1. library(ggrepel)

# %%
install.packages('patchwork')
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
library(scales)
# library(ggrepel)
library(patchwork)

# %% [markdown]
# # Homework Assignments

# %% [markdown]
# ## 9.2.1 Exercises

# %% [markdown]
# 1. Create a scatterplot of hwy vs. displ where the points are pink filled in triangles.

# %%
ggplot(mpg, aes(x = hwy, y = displ)) +
    geom_point(shape = 17, color = 'pink')
# Out:
# plot without title

# %% [markdown]
# 2. Why did the following code not result in a plot with blue points?
# ```r
# ggplot(mpg) +
#   geom_point(aes(x = displ, y = hwy, color = "blue"))
# ```

# %% [markdown]
# Answer: Because there isn't any separation from the aesthetics so color is being treated as a category to sort on. By adding a parenthesis and then continuing with color this makes the points blue.

# %%
ggplot(mpg) +
    geom_point(aes(x = displ, y =hwy) , color = 'blue')
# Out:
# plot without title

# %% [markdown]
# 3. What does the stroke aesthetic do? What shapes does it work with? (Hint: use ?geom_point)

# %% [markdown]
# Answer: It modifies the width of the border of points. It works with point plots (circular data points).

# %% [markdown]
# 4. What happens if you map an aesthetic to something other than a variable name, like aes(color = displ < 5)? Note, you’ll also need to specify x and y.

# %% [markdown]
# Answer: It colors it based on the condition you enter. It colors based on True or False scale.

# %%
ggplot(mpg, aes(x = displ, y = hwy)) +
    geom_point(aes(color = displ < 5))
# Out:
# plot without title

# %% [markdown]
# ## 9.3.1 Exercises

# %% [markdown]
# 1. What geom would you use to draw a line chart? A boxplot? A histogram? An area chart?

# %% [markdown]
# Answer: For line chart, use geom_line(). Boxplot use geom_boxplot(). Histogram use geom_histogram(). And for area chart use geom_area().

# %% [markdown]
# 2. Earlier in this chapter we used show.legend without explaining it:
# ```r
# ggplot(mpg, aes(x = displ, y = hwy)) +
#   geom_smooth(aes(color = drv), show.legend = FALSE)
# ```
# What does show.legend = FALSE do here? What happens if you remove it? Why do you think we used it earlier?

# %% [markdown]
# Answer: It removes the right hand legend that tells what the lines are colored by. If you remove show.legend = FALSE, it will show the legend as default. They did this to compare to the group function not including a legend so that it matched the other graphs.

# %% [markdown]
# 3. What does the se argument to geom_smooth() do?

# %% [markdown]
# Answer: It displays the confidence interval around the smoothing. It's true by default.

# %% [markdown]
# 4. Recreate the R code necessary to generate the following graphs. Note that wherever a categorical variable is used in the plot, it’s drv.

# %%
ggplot(mpg, aes(x = displ, y = hwy)) +
    geom_point() +
    geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %%
ggplot(mpg, aes(x = displ, y = hwy)) +
    geom_point() +
    geom_smooth(aes(group = drv), se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %%
ggplot(mpg, aes(x = displ, y = hwy, color = drv)) +
    geom_point() +
    geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %%
ggplot(mpg, aes(x = displ, y = hwy)) +
    geom_point(aes(color = drv)) +
    geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %%
ggplot(mpg, aes(x = displ, y = hwy)) +
    geom_point(aes(color = drv)) +
    geom_smooth(aes(linetype = drv), se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %%
ggplot(mpg, aes(x = displ, y = hwy)) +
    geom_point(aes(stroke = 2), color = 'white') +
    geom_point(aes(color = drv))
# Out:
# plot without title

# %% [markdown]
# ## 9.4.1 Exercises

# %% [markdown]
# 1. What happens if you facet on a continuous variable?

# %% [markdown]
# Answer: It maps a different facet for each unique value of the continuous variable.

# %%
ggplot(mpg, aes(x = displ, y = hwy)) +
    geom_point() +
    facet_wrap(~cty)
# Out:
# plot without title

# %% [markdown]
# 2. What do the empty cells in the plot above with facet_grid(drv ~ cyl) mean? Run the following code. How do they relate to the resulting plot?
# ```r
# ggplot(mpg) +
#   geom_point(aes(x = drv, y = cyl))
# ```

# %% [markdown]
# Answer: The empty facets are where there isn't a value for drv or cyl.

# %%
ggplot(mpg) + 
  geom_point(aes(x = drv, y = cyl))
# Out:
# plot without title

# %% [markdown]
# 3. What plots does the following code make? What does . do?
# ```r
# ggplot(mpg) +
#   geom_point(aes(x = displ, y = hwy)) +
#   facet_grid(drv ~ .)
#
# ggplot(mpg) +
#   geom_point(aes(x = displ, y = hwy)) +
#   facet_grid(. ~ cyl)
# ```

# %% [markdown]
# Answer: It facets the first with only drv and the second with cyl both as grids. However, in the first it maps it horizontally and the second vertically. Using the . allows the grid to not facet on the opposite side.

# %%
ggplot(mpg) + 
  geom_point(aes(x = displ, y = hwy)) +
  facet_grid(drv ~ .)

ggplot(mpg) + 
  geom_point(aes(x = displ, y = hwy)) +
  facet_grid(. ~ cyl)
# Out:
# plot without title
# plot without title

# %% [markdown]
# 4. Take the first faceted plot in this section:
# ```r
# ggplot(mpg) +
#   geom_point(aes(x = displ, y = hwy)) +
#   facet_wrap(~ cyl, nrow = 2)
# ```
# What are the advantages to using faceting instead of the color aesthetic? What are the disadvantages? How might the balance change if you had a larger dataset?

# %% [markdown]
# Answer: It allows you to view each of the different combinations of categories separately. You can quickly see if there's a lot of points attributed to a certain variable/quality or not. With color however, you can see a wide view of the points and get a larger general sense of the trend rather than having to look at each individual point. If you have a larger dataset, using color would be helpful for viewing the large trend but for viewing more specifics, using the facets would help.

# %%
ggplot(mpg) + 
  geom_point(aes(x = displ, y = hwy)) + 
  facet_wrap(~ cyl, nrow = 2)
# Out:
# plot without title

# %% [markdown]
# 5. Read ?facet_wrap. What does nrow do? What does ncol do? What other options control the layout of the individual panels? Why doesn’t facet_grid() have nrow and ncol arguments?

# %% [markdown]
# Answer: nrow specifies the number of rows and ncol specifies the number of columns in the facets. scales, as.table, and dir can also control the layout of the panels. facet_grid() doesn't have nrow and ncol arguments because it is specified on the group quality you assign. You can't remove rows/add rows if they don't exist in the qualities listed. For facet_wrap() you can control where the facets are placed.

# %% [markdown]
# 6. Which of the following plots makes it easier to compare engine size (displ) across cars with different drive trains? What does this say about when to place a faceting variable across rows or columns?
# ```r
# ggplot(mpg, aes(x = displ)) +
#   geom_histogram() +
#   facet_grid(drv ~ .)
#
# ggplot(mpg, aes(x = displ)) +
#   geom_histogram() +
#   facet_grid(. ~ drv)
# ```

# %% [markdown]
# Answer: The first is easier to view. This is because the values are spread longer apart and the bars themselves are easier to compare. With the second, they are a lot closer together and it makes it harder to discern each individual one. More values would be better faceted in columns. Less values would be better faceted in rows.

# %%
ggplot(mpg, aes(x = displ)) + 
  geom_histogram() + 
  facet_grid(drv ~ .)

ggplot(mpg, aes(x = displ)) + 
  geom_histogram() +
  facet_grid(. ~ drv)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %% [markdown]
# 7. Recreate the following plot using facet_wrap() instead of facet_grid(). How do the positions of the facet labels change?
# ```r
# ggplot(mpg) +
#   geom_point(aes(x = displ, y = hwy)) +
#   facet_grid(drv ~ .)
# ```

# %% [markdown]
# Answer: The facet labels go above the plot now instead of over on the side.

# %%
ggplot(mpg) + 
  geom_point(aes(x = displ, y = hwy)) +
  facet_wrap(~drv, dir = "v")
# Out:
# plot without title

# %% [markdown]
# ## 9.5.1 Exercises

# %% [markdown]
# 1. What is the default geom associated with stat_summary()? How could you rewrite the previous plot to use that geom function instead of the stat function?

# %% [markdown]
# Answer: It's associated with geom_pointrange(). You'd find the min, max and median values and group those. You'd then utilize the min, and max for the function plot with midpoint as the y and cut as x.

# %%
diamonds |>
  group_by(cut) |>
  summarize(
    lower = min(depth),
    upper = max(depth),
    midpoint = median(depth)
  ) |>
  ggplot(aes(x = cut, y = midpoint)) +
  geom_pointrange(aes(ymin = lower, ymax = upper))
# Out:
# plot without title

# %% [markdown]
# 2. What does geom_col() do? How is it different from geom_bar()?

# %% [markdown]
# Answer: geom_bar() makes the height of the bar proportional to the number of cases in each group and uses stat_count(). geom_col() makes the heights of the bars represent values in the data and uses stat_identity().

# %% [markdown]
# 3. Most geoms and stats come in pairs that are almost always used in concert. Make a list of all the pairs. What do they have in common? (Hint: Read through the documentation.)

# %% [markdown]
# Answer:
# - geom_bar() and stat_count()
# - geom_histogram() and stat_bin()
# - geom_point() and stat_identity()
# - geom_density() and stat_density()
# - geom_boxplot() and stat_boxplot() etc etc.

# %% [markdown]
# 4. What variables does stat_smooth() compute? What arguments control its behavior?

# %% [markdown]
# Answer:
# - after_stat(y) or after_stat(x) - predicted value
# - after_stat(ymin) or after_stat(xmin) - lower pointwise confidence interval around the mean
# - after_stat(ymax) or after_stat(xmax) - upper pointwise confidence interval around the mean
# - after_stat(se) - standard error
#
# Seems that some depend on orientation arguments

# %% [markdown]
# 5. In our proportion bar chart, we needed to set group = 1. Why? In other words, what is the problem with these two graphs?
# ```r
# ggplot(diamonds, aes(x = cut, y = after_stat(prop))) +
#   geom_bar()
# ggplot(diamonds, aes(x = cut, fill = color, y = after_stat(prop))) +
#   geom_bar()
# ```

# %% [markdown]
# Answer: The graphs have all the bars based on each proportion. It causes them all to appear the same and not have any differences.

# %%
ggplot(diamonds, aes(x = cut, y = after_stat(prop))) + 
  geom_bar()
ggplot(diamonds, aes(x = cut, fill = color, y = after_stat(prop))) + 
  geom_bar()
# Out:
# plot without title
# plot without title

# %% [markdown]
# ## 9.6.1 Exercises

# %% [markdown]
# 1. What is the problem with the following plot? How could you improve it?
# ```r
# ggplot(mpg, aes(x = cty, y = hwy)) +
#   geom_point()
# ```

# %% [markdown]
# Answer: The points aren't all shown and are rounded so that there aren't all the full amount shown. To fix this, use position = 'jitter' to add random noise to each point.

# %%
ggplot(mpg, aes(x = cty, y = hwy)) + 
  geom_point()
# Out:
# plot without title

# %% [markdown]
# 2. What, if anything, is the difference between the two plots? Why?
# ```r
# ggplot(mpg, aes(x = displ, y = hwy)) +
#   geom_point()
# ggplot(mpg, aes(x = displ, y = hwy)) +
#   geom_point(position = "identity")
# ```

# %% [markdown]
# Answer: They show the same thing because the position value is set to 'identity' which won't adjust the position of the points.

# %%
ggplot(mpg, aes(x = displ, y = hwy)) +
  geom_point()
ggplot(mpg, aes(x = displ, y = hwy)) +
  geom_point(position = "identity")
# Out:
# plot without title
# plot without title

# %% [markdown]
# 3. What parameters to geom_jitter() control the amount of jittering?

# %% [markdown]
# Answer: width and height control the amount.

# %% [markdown]
# 4. Compare and contrast geom_jitter() with geom_count().

# %% [markdown]
# Answer: geom_jitter() adds random noise to the points and geom_count() changes the sizes of each point based on the amount of observations at that location.

# %% [markdown]
# 5. What’s the default position adjustment for geom_boxplot()? Create a visualization of the mpg dataset that demonstrates it.

# %% [markdown]
# Answer: It is set at 'dodge2'

# %%
ggplot(mpg, aes(x = displ, y = hwy)) +
    geom_boxplot(position = 'dodge2')
# Out:
# Warning message:
# “Continuous x aesthetic
# ℹ did you forget `aes(group = ...)`?”
# plot without title

# %% [markdown]
# ## 9.7.1 Exercises

# %% [markdown]
# 1. Turn a stacked bar chart into a pie chart using coord_polar().

# %%
ggplot(diamonds) + 
    geom_bar(aes(x = cut, fill = cut), show.legend = FALSE, width = 1) + 
    theme(aspect.ratio = 1) +
    coord_flip()

ggplot(diamonds) + 
    geom_bar(aes(x = cut, fill = cut), show.legend = FALSE, width = 1) + 
    theme(aspect.ratio = 1) +
    coord_polar()
# Out:
# plot without title
# plot without title

# %% [markdown]
# 2. What’s the difference between coord_quickmap() and coord_map()?

# %% [markdown]
# Answer: coord_quickmap() projects a portion of the earth, which is approximately spherical, onto a flat 2D plane - it doesn't preserve straight lines. coord_map() does quick approximation that also preserves straight lines. It works best for smaller areas closer to the equator.

# %% [markdown]
# 3. What does the following plot tell you about the relationship between city and highway mpg? Why is coord_fixed() important? What does geom_abline() do?
# ```r
# ggplot(data = mpg, mapping = aes(x = cty, y = hwy)) +
#   geom_point() +
#   geom_abline() +
#   coord_fixed()
# ```

# %% [markdown]
# Answer: hwy mpg is always larger than cty mpg. coord_fixed() makes the axis forced to represent the number of units on the y-axis equivalent to one unit on the x-axis. geom_abline() adds a line for reference to the plot.

# %%
ggplot(data = mpg, mapping = aes(x = cty, y = hwy)) +
  geom_point() + 
  geom_abline() +
  coord_fixed()
# Out:
# plot without title

# %% [markdown]
# ## 10.3.3 Exercises

# %% [markdown]
# 1. Explore the distribution of each of the x, y, and z variables in diamonds. What do you learn? Think about a diamond and how you might decide which dimension is the length, width, and depth.

# %% [markdown]
# Answer: The y values are very close on the lower side of y. The z values are similar but slightly shorter than y. The x values are a lot more spread and located on the right side of x (around the same height as the others). I'd classify a diamond with y as the length, x as the width, and z as the depth.

# %%
ggplot(diamonds, aes(x = y)) + 
  geom_histogram(binwidth = 0.5)

ggplot(diamonds, aes(x = z)) + 
  geom_histogram(binwidth = 0.5)

ggplot(diamonds, aes(x = x)) + 
  geom_histogram(binwidth = 0.5)
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# 2. Explore the distribution of price. Do you discover anything unusual or surprising? (Hint: Carefully think about the binwidth and make sure you try a wide range of values.)

# %% [markdown]
# Answer: It seems that there's a very large amount of cheaper priced diamonds and going up in price is related to a lower count.

# %%
ggplot(diamonds, aes(x = price)) +
    geom_histogram(binwidth = 1000)
# Out:
# plot without title

# %% [markdown]
# 3. How many diamonds are 0.99 carat? How many are 1 carat? What do you think is the cause of the difference?

# %% [markdown]
# Answer: 23 are 0.99. 1558 are 1 carat. I think that 1 carat diamonds may be more common than 0.99 since 0.99 is a more specific value than just 1.

# %%
smaller_carat <- diamonds |> 
  filter(carat == 0.99)

smaller_carat

larger_carat<- diamonds |> 
  filter(carat == 1.0)

larger_carat
# Out:
#    carat cut       color clarity depth table price x    y    z
# 1  0.99  Fair      I     SI2     68.1  56    2811  6.21 6.06 4.18
# 2  0.99  Fair      J     SI1     55.0  61    2812  6.72 6.67 3.68
# 3  0.99  Fair      J     SI1     58.0  67    2949  6.57 6.50 3.79
# 4  0.99  Fair      I     SI1     60.7  66    3337  6.42 6.34 3.87
# 5  0.99  Fair      H     VS2     71.6  57    3593  5.94 5.80 4.20
# 6  0.99  Very Good J     SI1     60.3  57    4002  6.44 6.49 3.90
# 7  0.99  Good      F     SI2     63.3  54    4052  6.36 6.43 4.05
# 8  0.99  Premium   F     SI2     60.6  61    4075  6.45 6.38 3.89
# 9  0.99  Ideal     I     SI1     61.8  57    4763  6.40 6.42 3.96
# 10 0.99  Very Good E     SI2     61.8  59    4780  6.30 6.33 3.90
# 11 0.99  Very Good F     SI2     61.2  56    4852  6.40 6.45 3.93
# 12 0.99  Very Good G     SI1     62.8  56    4863  6.34 6.36 3.99
# 13 0.99  Very Good D     SI2     62.5  57    4993  6.30 6.34 3.95
# ...

# %% [markdown]
# 4. Compare and contrast coord_cartesian() vs. xlim() or ylim() when zooming in on a histogram. What happens if you leave binwidth unset? What happens if you try and zoom so only half a bar shows?

# %% [markdown]
# Answer: If you leave binwidth unset it causes a popup that says to pick a better value. You can't see as many variations in the bars with it not set (it turns smooth at smaller points of contrast). If you zoom in really far it can eventually not show any data points.

# %%
ggplot(diamonds, aes(x = y)) + 
  geom_histogram() +
  coord_cartesian(ylim = c(0, 50))
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(diamonds, aes(x = y)) + 
  geom_histogram() +
  coord_cartesian(xlim = c(0, 20))
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# ## 10.4.1 Exercises

# %% [markdown]
# 1. What happens to missing values in a histogram? What happens to missing values in a bar chart? Why is there a difference in how missing values are handled in histograms and bar charts?

# %% [markdown]
# Answer: In a histogram, NA values are ignored. In a bar chart, the NA values are added to a separate category and treated as values.

# %% [markdown]
# 2. What does na.rm = TRUE do in mean() and sum()?

# %% [markdown]
# Answer: Tells the function if NA values should be removed from calculating the mean or sum of variables

# %% [markdown]
# 3. Recreate the frequency plot of scheduled_dep_time colored by whether the flight was cancelled or not. Also facet by the cancelled variable. Experiment with different values of the scales variable in the faceting function to mitigate the effect of more non-cancelled flights than cancelled flights.

# %%
nycflights13::flights |> 
  mutate(
    cancelled = is.na(dep_time),
    sched_hour = sched_dep_time %/% 100,
    sched_min = sched_dep_time %% 100,
    sched_dep_time = sched_hour + (sched_min / 60)
  ) |> 
  ggplot(aes(x = sched_dep_time)) + 
  geom_freqpoly(aes(color = cancelled), binwidth = 1/4)
  facet_wrap(~cancelled, scales = 'free_x')
# Out:
# <ggproto object: Class FacetWrap, Facet, gg>
#     compute_layout: function
#     draw_back: function
#     draw_front: function
#     draw_labels: function
#     draw_panels: function
#     finish_data: function
#     init_scales: function
#     map_data: function
#     params: list
#     setup_data: function
#     setup_params: function
#     shrink: TRUE
#     train_scales: function
#     vars: function
#     super:  <ggproto object: Class FacetWrap, Facet, gg>
# plot without title

# %% [markdown]
# ## 11.2.1 Exercises

# %% [markdown]
# 1. Create one plot on the fuel economy data with customized title, subtitle, caption, x, y, and color labels.

# %%
ggplot(mpg, aes(x = displ, y = cty)) +
    geom_point(aes(color = drv)) +
    geom_smooth(se = FALSE) +
    labs(
        x = 'Engine Displacement, (L)',
        y = 'City Miles per Gallon (mpg)',
        color = 'Drive Train Type',
        title = 'Fuel efficiency appears to decrease with type of vehicle drive train',
        subtitle = 'Front-wheel and four-wheel drive vehicles have a better fuel \n efficiency in city mpg due to more control than rear-wheel drive',
        caption = 'Data from fueleconomy.gov'
    )
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %% [markdown]
# 2. Recreate the following plot using the fuel economy data. Note that both the colors and shapes of points vary by type of drive train.

# %%
ggplot(mpg, aes(x = cty, y = hwy)) +
    geom_point(aes(color = drv, shape = drv)) +
    labs(
        x = 'City MPG',
        y = 'Highway MPG',
        color = 'Type of drive train',
        shape = 'Type of drive train'
    )
# Out:
# plot without title

# %% [markdown]
# 3. Take an exploratory graphic that you’ve created in the last month, and add informative titles to make it easier for others to understand.

# %%
ggplot(mpg, aes(x = displ, y = hwy)) + 
  geom_point(aes(color = class)) + 
  geom_smooth() +
  labs(
    x = 'Engine Displacement (L)',
    y = 'Highway MPG',
    color = 'Car Class',
    title = 'Fuel efficiency tends to decrease with size of car',
    subtitle = '2 Seater cars are an exception and do not fit the general trend',
    caption = 'Data from fueleconomy.gov'
  )
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %% [markdown]
# ## 11.3.1 Exercises

# %% [markdown]
# 1. Use geom_text() with infinite positions to place text at the four corners of the plot.

# %%
label <- tribble(
  ~displ, ~hwy, ~label, ~vjust, ~hjust,
  Inf, Inf, "Top right", "top", "right",
  Inf, -Inf, "Bottom right", "bottom", "right",
  -Inf, Inf, "Top left", "top", "left",
  -Inf, -Inf, "Bottom left", "bottom", "left"
)

ggplot(mpg, aes(displ, hwy)) +
  geom_point() +
  geom_text(aes(label = label, vjust = vjust, hjust = hjust), data = label)
# Out:
# plot without title

# %% [markdown]
# 2. Use annotate() to add a point geom in the middle of your last plot without having to create a tibble. Customize the shape, size, or color of the point.

# %%
x_mid = (min(mpg$displ) + max(mpg$displ))/2
y_mid = (min(mpg$hwy) + max(mpg$hwy))/2

ggplot(mpg, aes(displ, hwy)) +
  geom_point() +
  geom_text(aes(label = label, vjust = vjust, hjust = hjust), data = label) +
  annotate(
    geom = "point",
    x = x_mid,
    y = y_mid,
    shape = 4,
    size = 10,
    color = "blue")
# Out:
# plot without title

# %% [markdown]
# 3. How do labels with geom_text() interact with faceting? How can you add a label to a single facet? How can you put a different label in each facet? (Hint: Think about the dataset that is being passed to geom_text().)

# %% [markdown]
# Answer: labels with geom_text() will facet to whichever data points it matches to. To make a single facet label, you'd have to make a df with the points you want labelled and the rest as NA values so they aren't labelled on the other facets. To put a label in each different facet it's similar to making the df for the single facet label but you'd make a label for each facet instead of only one.

# %% [markdown]
# 4. What arguments to geom_label() control the appearance of the background box?

# %% [markdown]
# Answer: label.padding, label.r, and label.size

# %% [markdown]
# 5. What are the four arguments to arrow()? How do they work? Create a series of plots that demonstrate the most important options.

# %% [markdown]
# Answer: angle, length, ends, type

# %%
trend_text <- "Larger engine sizes tend to have lower fuel economy." |>
  str_wrap(width = 30)

ggplot(mpg, aes(x = displ, y = hwy)) +
  geom_point() +
  annotate(
    geom = "label", x = 3.5, y = 38,
    label = trend_text,
    hjust = "left", color = "red"
  ) +
  annotate(
    geom = "segment",
    x = 3, y = 35, xend = 5, yend = 25, color = "red",
    arrow = arrow(type = "open")
  )
# Out:
# plot without title

# %%
trend_text <- "Larger engine sizes tend to have lower fuel economy." |>
  str_wrap(width = 30)

ggplot(mpg, aes(x = displ, y = hwy)) +
  geom_point() +
  annotate(
    geom = "label", x = 3.5, y = 38,
    label = trend_text,
    hjust = "left", color = "red"
  ) +
  annotate(
    geom = "segment",
    x = 3, y = 35, xend = 5, yend = 25, color = "red",
    arrow = arrow(length = unit(1, 'inches'))
  )
# Out:
# plot without title

# %%
trend_text <- "Larger engine sizes tend to have lower fuel economy." |>
  str_wrap(width = 30)

ggplot(mpg, aes(x = displ, y = hwy)) +
  geom_point() +
  annotate(
    geom = "label", x = 3.5, y = 38,
    label = trend_text,
    hjust = "left", color = "red"
  ) +
  annotate(
    geom = "segment",
    x = 3, y = 35, xend = 5, yend = 25, color = "red",
    arrow = arrow(angle = 60)
  )
# Out:
# plot without title

# %%
trend_text <- "Larger engine sizes tend to have lower fuel economy." |>
  str_wrap(width = 30)

ggplot(mpg, aes(x = displ, y = hwy)) +
  geom_point() +
  annotate(
    geom = "label", x = 3.5, y = 38,
    label = trend_text,
    hjust = "left", color = "red"
  ) +
  annotate(
    geom = "segment",
    x = 3, y = 35, xend = 5, yend = 25, color = "red",
    arrow = arrow(ends = "both")
  )
# Out:
# plot without title

# %% [markdown]
# ## 11.4.6 Exercises

# %% [markdown]
# 1. Why doesn’t the following code override the default scale?
# ```r
# df <- tibble(
#   x = rnorm(10000),
#   y = rnorm(10000)
# )
#
# ggplot(df, aes(x, y)) +
#   geom_hex() +
#   scale_color_gradient(low = "white", high = "red") +
#   coord_fixed()
# ```

# %% [markdown]
# Answer: Because it's using a hex it needs to have the fill changed not the color variable.

# %%
df <- tibble(
  x = rnorm(10000),
  y = rnorm(10000)
)

ggplot(df, aes(x, y)) +
  geom_hex() +
  scale_color_gradient(low = "white", high = "red") +
  coord_fixed()
# Out:
# plot without title

# %%
df <- tibble(
  x = rnorm(10000),
  y = rnorm(10000)
)

ggplot(df, aes(x, y)) +
  geom_hex() +
  scale_fill_gradient(low = "white", high = "red") +
  coord_fixed()
# Out:
# plot without title

# %% [markdown]
# 2. What is the first argument to every scale? How does it compare to labs()?

# %% [markdown]
# Answer: name = () in labs() it's title = ()

# %% [markdown]
# 3. Change the display of the presidential terms by:
#
# - Combining the two variants that customize colors and x axis breaks.
# - Improving the display of the y axis.
# - Labelling each term with the name of the president.
# - Adding informative plot labels.
# - Placing breaks every 4 years (this is trickier than it seems!).

# %% [markdown]
# Having trouble understanding how to complete this one...

# %% [markdown]
# 4. First, create the following plot. Then, modify the code using override.aes to make the legend easier to see.
# ```r
# ggplot(diamonds, aes(x = carat, y = price)) +
#   geom_point(aes(color = cut), alpha = 1/20)
# ```

# %%
ggplot(diamonds, aes(x = carat, y = price)) +
  geom_point(aes(color = cut), alpha = 1/20) +
  guides(color = guide_legend(override.aes = list(size = 4, alpha = 0.5)))
# Out:
# plot without title

# %% [markdown]
# ## 11.5.1 Exercises

# %% [markdown]
# 1. Pick a theme offered by the ggthemes package and apply it to the last plot you made.

# %%
ggplot(diamonds, aes(x = carat, y = price)) +
  geom_point(aes(color = cut), alpha = 1/20) +
  guides(color = guide_legend(override.aes = list(size = 4, alpha = 0.5))) +
  theme_light()
# Out:
# plot without title

# %% [markdown]
# 2. Make the axis labels of your plot blue and bolded.

# %%
ggplot(diamonds, aes(x = carat, y = price)) +
  geom_point(aes(color = cut), alpha = 1/20) +
  guides(color = guide_legend(override.aes = list(size = 4, alpha = 0.5))) +
  theme_light() +
  theme(axis.text = element_text(face = "bold", color = "blue"))
# Out:
# plot without title
