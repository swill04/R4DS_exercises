# %%
library(ggplot2)
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 4.2.3”

# %%
daily_accidents <- readr::read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-04-22/daily_accidents.csv')
daily_accidents_420 <- readr::read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-04-22/daily_accidents_420.csv')
# Out:
# Rows: 9132 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl  (1): fatalities_count
# date (1): date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 9170 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl  (1): fatalities_count
# lgl  (1): e420
# date (1): date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
daily_accidents_420
# Out:
#      date       e420  fatalities_count
# 1    1992-01-01 FALSE 144
# 2    1992-01-02 FALSE 111
# 3    1992-01-07 FALSE  85
# 4    1992-01-12 FALSE 127
# 5    1992-01-03 FALSE 182
# 6    1992-01-17 FALSE 130
# 7    1992-01-13 FALSE 119
# 8    1992-01-20 FALSE 120
# 9    1992-01-14 FALSE 106
# 10   1992-01-11 FALSE 124
# 11   1992-01-18 FALSE 147
# 12   1992-01-16 FALSE  82
# 13   1992-01-05 FALSE  99
# 14   1992-01-25 FALSE 150
# 15   1992-01-24 FALSE 173
# 16   1992-01-15 FALSE  91
# 17   1992-01-21 FALSE 115
# 18   1992-01-26 FALSE 118
# 19   1992-01-29 FALSE  99
# 20   1992-01-28 FALSE  91
# 21   1992-01-30 FALSE 113
# 22   1992-01-23 FALSE 149
# 23   1992-01-22 FALSE 103
# 24   1992-01-10 FALSE 129
# 25   1992-01-08 FALSE 126
# 26   1992-01-09 FALSE 117
# 27   1992-01-04 FALSE 152
# 28   1992-02-01 FALSE 145
# 29   1992-02-03 FALSE 112
# 30   1992-02-08 FALSE 190
# ⋮    ⋮          ⋮     ⋮
# 9141 2016-04-20 FALSE  81
# 9142 2016-05-24 FALSE 110
# 9143 2016-07-06 FALSE 126
# 9144 2016-08-11 FALSE 154
# 9145 2016-09-25 FALSE 163
# 9146 2016-01-03 FALSE 106
# 9147 2016-01-19 FALSE  89
# 9148 2016-01-24 FALSE  96
# 9149 2016-02-15 FALSE 120
# 9150 2016-02-19 FALSE 160
# 9151 2016-01-12 FALSE 119
# 9152 2016-01-20 FALSE 116
# 9153 2016-01-29 FALSE 142
# 9154 2016-03-12 FALSE 146
# 9155 2016-03-21 FALSE 142
# 9156 2016-04-19 FALSE 135
# 9157 2016-04-16 FALSE 181
# 9158 2016-05-16 FALSE 141
# 9159 2016-05-17 FALSE 104
# 9160 2016-05-20 FALSE 166
# 9161 2016-06-22 FALSE 155
# 9162 2016-08-26 FALSE 133
# 9163 2016-07-07 FALSE 131
# 9164 2016-06-02 FALSE 119
# 9165 2016-09-03 FALSE 175
# 9166 2016-09-28 FALSE 134
# 9167 2016-11-09 FALSE 131
# 9168 2016-12-19 FALSE 106
# 9169 2016-12-29 FALSE 135
# 9170 2016-04-15 FALSE 125

# %%
accident_420_plot <- ggplot(daily_accidents_420, aes(date, fatalities_count)) +
    geom_point(aes(color = e420))
accident_420_plot
# Out:
# plot without title

# %%
accident_plot <- ggplot(daily_accidents, aes(date, fatalities_count)) +
    geom_point(aes(color = date))
accident_plot
# Out:
# plot without title
